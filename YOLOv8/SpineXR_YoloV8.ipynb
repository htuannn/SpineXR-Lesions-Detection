# %%
# download data
# !pip install gdown --upgrade
# !gdown --id 1-3JOV67ee7JmyRFiaHq6jEgkw4j6JyGo
# !unzip data.zip

# %%
# download model
# !gdown --id 1DfLPSrWK7qVmMXX3ZzK08B6WPsDp2mgj
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1DfLPSrWK7qVmMXX3ZzK08B6WPsDp2mgj
# From (redirected): https://drive.google.com/uc?id=1DfLPSrWK7qVmMXX3ZzK08B6WPsDp2mgj&confirm=t&uuid=df571ebd-27da-40ab-bb0e-f57d3c07ca9d
# To: /content/yolov8-65.3.pt
# 100% 89.5M/89.5M [00:01<00:00, 49.7MB/s]

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.1/593.1 kB 23.7 MB/s eta 0:00:00
# ...

# %%
# create config
# %%writefile data.yaml

train: data/images/train
val: data/images/val
test: data/images/test


nc: 7
names: ["Disc_space_narrowing", "Foraminal_stenosis", "Osteophytes", "Other_lesions", "Spondylolysthesis", "Surgical_implant", "Vertebral_collapse"]
# Out:
# Writing data.yaml

# %%
# !mkdir datasets
# !cp -r content/data datasets

# %%
from ultralytics import YOLO
# train model
# !yolo task=detect \
      mode=train \
      model=yolov8s.pt \
      data=data.yaml \
      epochs=300 \
      imgsz=640 \
      batch=48 \
      optimizer=Adam

# %%
# predict testset
from ultralytics import YOLO
import cv2

model = YOLO("/content/yolov8-65.3.pt")
model.predict(source = '/content/content/data/images/test', show = True, save=True)
cv2.waitKey(0)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# image 1/873 /content/content/data/images/test/005c62dd9be402dcd71211d8eb039295.jpg: 640x576 (no detections), 106.3ms
# image 2/873 /content/content/data/images/test/0101087b1bce56e91b17938ef1f3cdf0.jpg: 640x288 6 Osteophytess, 1 Spondylolysthesis, 112.4ms
# image 3/873 /content/content/data/images/test/0125a5126168264d64f8af434def76d6.jpg: 640x256 1 Osteophytes, 81.8ms
# image 4/873 /content/content/data/images/test/018a409b6123d6fe2c7bdf528b15ec3c.jpg: 640x544 1 Osteophytes, 62.9ms
# image 5/873 /content/content/data/images/test/01bf4f115b6a12903e336f2549e77050.jpg: 640x288 1 Osteophytes, 11.4ms
# image 6/873 /content/content/data/images/test/01e8ea3c498eb96bf39a1f019680aa7f.jpg: 640x352 6 Osteophytess, 1 Surgical_implant, 65.5ms
# image 7/873 /content/content/data/images/test/02376fdfd205eed32f83bfe39a2d0ffe.jpg: 640x608 7 Osteophytess, 67.5ms
# ...

# %%
# eval validation set
# !yolo val model=/content/yolov8-65.3.pt data=/content/data.yaml split=test save=True conf=0.6
# Out:
# Ultralytics YOLOv8.0.112 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients
# val: Scanning /content/data/labels/test.cache... 873 images, 0 backgrounds, 0 corrupt: 100% 873/873 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/data/images/test/078075701bb83b1ac2f833c0576a33fd.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /content/data/images/test/0881a2daafeb7f9514bd038be28e1731.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /content/data/images/test/0ccf49e003ad267062de0c14bb4d4088.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /content/data/images/test/0eb0109248f23d97ef84f69550e3904c.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /content/data/images/test/2e98d68eb858603f49f9c6185a0fa333.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/data/images/test/3f503dc886d4105b86e199f6ef3bd722.jpg: 1 duplicate labels removed
# ...
